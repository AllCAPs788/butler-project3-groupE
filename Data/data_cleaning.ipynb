# %%
import pandas as pd

# %%
# read csv files

books = pd.read_csv("books.csv")
books_2 = pd.read_csv("books_2.csv")

# %%
# fill isbn column with leading zeros to make 10 digits (this csv file is missing the zeros)

books_2["isbn"] = books_2["isbn"].str.zfill(10)

# %%
# change isbn columns to strings (isbn numbers do sometimes contain the letter X)

books["isbn10"] = books["isbn10"].astype(str)
books_2["isbn"] = books_2["isbn"].astype(str)

# %%
#rename column for books dataframe to match books_2

books = books.rename(columns={"isbn10": "isbn"})

# %%
# inner join the dataframes on the isbn column

merged = pd.merge(books_2, books, on=["isbn"])

# %%
# display merged data

merged
# Out:
#       bookID                                            title_x  \
# 0          1  Harry Potter and the Half-Blood Prince (Harry ...
# 1          2  Harry Potter and the Order of the Phoenix (Har...
# 2          4  Harry Potter and the Chamber of Secrets (Harry...
# 3          5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4          8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...      ...                                                ...
# 5681   45546  Undaunted Courage: The Pioneering First Missio...
# 5682   45564                             Jonny Reb & Billy Yank
# 5683   45630                                  Whores for Gloria
# 5684   45631   Expelled from Eden: A William T. Vollmann Reader
# 5685   45633                        You Bright and Risen Angels
#
#                                               authors_x average_rating_x  \
# 0                            J.K. Rowling/Mary GrandPré             4.57
# 1                            J.K. Rowling/Mary GrandPré             4.49
# 2                                          J.K. Rowling             4.42
# 3                            J.K. Rowling/Mary GrandPré             4.56
# 4                            J.K. Rowling/Mary GrandPré             4.78
# ...                                                 ...              ...
# 5681                                 Stephen E. Ambrose             4.21
# 5682                                   Alexander Hunter             4.11
# 5683                                William T. Vollmann             3.69
# 5684  William T. Vollmann/Larry McCaffery/Michael He...             4.06
# 5685                                William T. Vollmann             4.08
#
#             isbn     isbn13_x language_code   num_pages  ratings_count_x  \
# 0     0439785960  9.78044E+12           eng         652          2095690
# 1     0439358078  9.78044E+12           eng         870          2153167
# 2     0439554896  9.78044E+12           eng         352             6333
# 3     043965548X  9.78044E+12           eng         435          2339585
# 4     0439682584  9.78044E+12           eng        2690            41428
# ...          ...          ...           ...         ...              ...
# 5681  074347788X  9.78074E+12           eng         592            41236
# 5682  1568520808  9.78157E+12           eng         635               14
# 5683  0140231579  9.78014E+12         en-US         160              932
# 5684  1560254416  9.78156E+12           eng         512              156
# 5685  0140110879  9.78014E+12           eng         635              783
#
#       text_reviews_count  ...  \
# 0                  27591  ...
# 1                  29221  ...
# 2                    244  ...
# 3                  36325  ...
# 4                    164  ...
# ...                  ...  ...
# 5681                1830  ...
# 5682                   2  ...
# 5683                 111  ...
# 5684                  20  ...
# 5685                  56  ...
#
#                                                 title_y  \
# 0       Harry Potter and the Half-Blood Prince (Book 6)
# 1     Harry Potter and the Order of the Phoenix (Boo...
# 2               Harry Potter and the Chamber of Secrets
# 3     Harry Potter and the Prisoner of Azkaban (Book 3)
# 4                                          Harry Potter
# ...                                                 ...
# 5681                                  Undaunted Courage
# 5682                          Johnny Reb and Billy Yank
# 5683                                  Whores for Gloria
# 5684                                 Expelled from Eden
# 5685                        You Bright and Risen Angels
#
#                                                subtitle  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     5 Years of Magic, Adventure, and Mystery at Ho...
# ...                                                 ...
# 5681  The Pioneering First Mission to Explore Americ...
# 5682                                                NaN
# 5683                                                NaN
# 5684                       A William T. Vollmann Reader
# 5685                                          A Cartoon
#
#                         authors_y        categories  \
# 0                   Rowling, J.K.  Juvenile Fiction
# 1                   Rowling, J.K.  Juvenile Fiction
# 2     J. K. Rowling;Mary GrandPre  Juvenile Fiction
# 3                   Rowling, J.K.  Juvenile Fiction
# 4                   J. K. Rowling  Juvenile Fiction
# ...                           ...               ...
# 5681           Stephen E. Ambrose         Explorers
# 5682             Alexander Hunter     United States
# 5683          William T. Vollmann           Fiction
# 5684                      Perseus           Fiction
# 5685          William T. Vollmann           Fiction
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=QzI0B...
# 1     http://books.google.com/books/content?id=OIJ5B...
# 2     http://books.google.com/books/content?id=h2Y-P...
# 3     http://books.google.com/books/content?id=IZN5B...
# 4     http://books.google.com/books/content?id=DAAAA...
# ...                                                 ...
# 5681  http://books.google.com/books/content?id=1egIO...
# 5682  http://books.google.com/books/content?id=z4LeI...
# 5683  http://books.google.com/books/content?id=mQA-P...
# 5684  http://books.google.com/books/content?id=Q_XQs...
# 5685  http://books.google.com/books/content?id=d0buA...
#
#                                             description published_year  \
# 0     When Harry Potter and the Half-Blood Prince op...         2015.0
# 1     In Harry Potter and the Order of the Phoenix, ...         2015.0
# 2     When the Chamber of Secrets is opened again at...         2003.0
# 3     For twelve long years, the dread fortress of A...         2015.0
# 4     The first five years of Harry Potter magic are...         2004.0
# ...                                                 ...            ...
# 5681  'This was much more than a bunch of guys out o...         2003.0
# 5682                                                NaN         1904.0
# 5683  From the acclaimed author of The Rainbow Stori...         1994.0
# 5684  No stranger to living and writing on the edge,...         2004.0
# 5685  This comic and surreal novel about the beastli...         1988.0
#
#      average_rating_y num_pages ratings_count_y
# 0                4.56     652.0       1944099.0
# 1                4.49     870.0       1996446.0
# 2                4.41     352.0          6267.0
# 3                4.55     435.0       2149872.0
# 4                4.78    2690.0         38872.0
# ...               ...       ...             ...
# 5681             4.22     592.0         38555.0
# 5682             4.11     635.0            13.0
# 5683             3.69     160.0           896.0
# 5684             4.05     512.0           156.0
# 5685             4.08     635.0           747.0
#
# [5686 rows x 24 columns]

# %%
# display all columns on the merged dataframe

merged.columns
# Out:
# Index(['bookID', 'title_x', 'authors_x', 'average_rating_x', 'isbn',
#        'isbn13_x', 'language_code', '  num_pages', 'ratings_count_x',
#        'text_reviews_count', 'publication_date', 'publisher', 'Unnamed: 12',
#        'isbn13_y', 'title_y', 'subtitle', 'authors_y', 'categories',
#        'thumbnail', 'description', 'published_year', 'average_rating_y',
#        'num_pages', 'ratings_count_y'],
#       dtype='object')

# %%
# drop duplicate/unnecessary columns

cleaned = merged.drop(["title_y", "subtitle", "authors_y", "isbn13_y", "average_rating_y", "  num_pages", \
                      "ratings_count_y", "Unnamed: 12"], axis=1)

# %%
# rename columns

cleaned = cleaned.rename(columns={"title_x": "title", "authors_x": "authors", "average_rating_x": "average_rating", \
                                 "isbn13_x": "isbn13", "ratings_count_x": "ratings_count"})

# %%
# only keep rows with English as the language

cleaned = cleaned[(cleaned["language_code"] == "eng") | (cleaned["language_code"] == "en-US") | \
                   (cleaned["language_code"] == "en-GB") | (cleaned["language_code"] == "en_CA") | \
                   (cleaned["language_code"] == "enm")]

# %%
# reset the index

cleaned = cleaned.reset_index(drop=True)

# %%
# show cleaned dataframe

cleaned
# Out:
#       bookID                                              title  \
# 0          1  Harry Potter and the Half-Blood Prince (Harry ...
# 1          2  Harry Potter and the Order of the Phoenix (Har...
# 2          4  Harry Potter and the Chamber of Secrets (Harry...
# 3          5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4          8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...      ...                                                ...
# 5675   45546  Undaunted Courage: The Pioneering First Missio...
# 5676   45564                             Jonny Reb & Billy Yank
# 5677   45630                                  Whores for Gloria
# 5678   45631   Expelled from Eden: A William T. Vollmann Reader
# 5679   45633                        You Bright and Risen Angels
#
#                                                 authors average_rating  \
# 0                            J.K. Rowling/Mary GrandPré           4.57
# 1                            J.K. Rowling/Mary GrandPré           4.49
# 2                                          J.K. Rowling           4.42
# 3                            J.K. Rowling/Mary GrandPré           4.56
# 4                            J.K. Rowling/Mary GrandPré           4.78
# ...                                                 ...            ...
# 5675                                 Stephen E. Ambrose           4.21
# 5676                                   Alexander Hunter           4.11
# 5677                                William T. Vollmann           3.69
# 5678  William T. Vollmann/Larry McCaffery/Michael He...           4.06
# 5679                                William T. Vollmann           4.08
#
#             isbn       isbn13 language_code  ratings_count  \
# 0     0439785960  9.78044E+12           eng        2095690
# 1     0439358078  9.78044E+12           eng        2153167
# 2     0439554896  9.78044E+12           eng           6333
# 3     043965548X  9.78044E+12           eng        2339585
# 4     0439682584  9.78044E+12           eng          41428
# ...          ...          ...           ...            ...
# 5675  074347788X  9.78074E+12           eng          41236
# 5676  1568520808  9.78157E+12           eng             14
# 5677  0140231579  9.78014E+12         en-US            932
# 5678  1560254416  9.78156E+12           eng            156
# 5679  0140110879  9.78014E+12           eng            783
#
#       text_reviews_count publication_date         publisher        categories  \
# 0                  27591        9/16/2006   Scholastic Inc.  Juvenile Fiction
# 1                  29221         9/1/2004   Scholastic Inc.  Juvenile Fiction
# 2                    244        11/1/2003        Scholastic  Juvenile Fiction
# 3                  36325         5/1/2004   Scholastic Inc.  Juvenile Fiction
# 4                    164        9/13/2004        Scholastic  Juvenile Fiction
# ...                  ...              ...               ...               ...
# 5675                1830        10/6/2003  Simon & Schuster         Explorers
# 5676                   2        5/31/1998         Not Avail     United States
# 5677                 111         2/1/1994     Penguin Books           Fiction
# 5678                  20       12/21/2004     Da Capo Press           Fiction
# 5679                  56        12/1/1988     Penguin Books           Fiction
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=QzI0B...
# 1     http://books.google.com/books/content?id=OIJ5B...
# 2     http://books.google.com/books/content?id=h2Y-P...
# 3     http://books.google.com/books/content?id=IZN5B...
# 4     http://books.google.com/books/content?id=DAAAA...
# ...                                                 ...
# 5675  http://books.google.com/books/content?id=1egIO...
# 5676  http://books.google.com/books/content?id=z4LeI...
# 5677  http://books.google.com/books/content?id=mQA-P...
# 5678  http://books.google.com/books/content?id=Q_XQs...
# 5679  http://books.google.com/books/content?id=d0buA...
#
#                                             description  published_year  \
# 0     When Harry Potter and the Half-Blood Prince op...          2015.0
# 1     In Harry Potter and the Order of the Phoenix, ...          2015.0
# 2     When the Chamber of Secrets is opened again at...          2003.0
# 3     For twelve long years, the dread fortress of A...          2015.0
# 4     The first five years of Harry Potter magic are...          2004.0
# ...                                                 ...             ...
# 5675  'This was much more than a bunch of guys out o...          2003.0
# 5676                                                NaN          1904.0
# 5677  From the acclaimed author of The Rainbow Stori...          1994.0
# 5678  No stranger to living and writing on the edge,...          2004.0
# 5679  This comic and surreal novel about the beastli...          1988.0
#
#       num_pages
# 0         652.0
# 1         870.0
# 2         352.0
# 3         435.0
# 4        2690.0
# ...         ...
# 5675      592.0
# 5676      635.0
# 5677      160.0
# 5678      512.0
# 5679      635.0
#
# [5680 rows x 16 columns]

# %%
# save cleaned dataframe to a csv file

cleaned.to_csv("cleaned_books.csv")
